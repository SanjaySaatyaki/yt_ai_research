# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjaySaatyaki/yt_ai_research/blob/main/4_tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
t = torch.tensor([[1,2,3],
                  [4,5,6]], dtype=torch.float32)

# %%
t.shape
# Out:
# torch.Size([2, 3])

# %%
t_falt = t.flatten()
t_falt.shape
# Out:
# torch.Size([6])

# %%
t_flat_start = t.flatten(start_dim=0)
t_flat_start
# Out:
# tensor([1., 2., 3., 4., 5., 6.])

# %%
d3_tensor = torch.tensor([[[1,2],
               [3,4]],
              [[5,6],
               [7,8]]])

# %%
d3_tensor
# Out:
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %%
d3_tensor.flatten(start_dim=1)
# Out:
# tensor([[1, 2, 3, 4],
#         [5, 6, 7, 8]])

# %%
t = torch.tensor([[1,2,3,4],
                  [5,6,7,8]])

# %%
t.shape
# Out:
# torch.Size([2, 4])

# %%
t.reshape(4,2)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6],
#         [7, 8]])

# %%
t = torch.tensor([[[1,3,4]]])
t_squeeze = t.squeeze()

# %%
t_squeeze
# Out:
# tensor([1, 3, 4])
