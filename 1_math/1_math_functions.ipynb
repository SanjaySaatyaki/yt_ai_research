# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjaySaatyaki/yt_ai_research/blob/main/1_math/1_math_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_values = np.linspace(0,10,100)
y_values = 2 * x_values

# %%
plt.figure(figsize=(8,5))
plt.plot(x_values,y_values, 'b-', linewidth=2, label="y=2x")
plt.xlabel('x')
plt.ylabel('y')
plt.title("Linear function: y=2x")
plt.grid(True)
plt.legend()
plt.show()

# %%
k_values = [1,2,3,0.5,-1]
x= np.linspace(-5,5,100)

plt.figure(figsize=(10,6))
for k in k_values:
  y = k*x
  plt.plot(x,y, label=f'y= {k}x',linewidth=2)

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()

# %%
x_values = np.linspace(-10,10,100)
y_values = x_values ** 2

plt.figure(figsize=(8,5))
plt.plot(x_values, y_values,linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
# Out:
# /tmp/ipython-input-3863061355.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
